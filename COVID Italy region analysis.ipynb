# %% [markdown]
# # COVID Italy Region Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= pd.read_csv('covid19_italy_region.csv')

# %%
data.head()
# Out:
#    SNo                 Date Country  RegionCode    RegionName   Latitude  \
# 0    0  2020-02-24T18:00:00     ITA          13       Abruzzo  42.351222
# 1    1  2020-02-24T18:00:00     ITA          17    Basilicata  40.639471
# 2    2  2020-02-24T18:00:00     ITA           4  P.A. Bolzano  46.499335
# 3    3  2020-02-24T18:00:00     ITA          18      Calabria  38.905976
# 4    4  2020-02-24T18:00:00     ITA          15      Campania  40.839566
#
#    Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0  13.398438                     0                      0
# 1  15.805148                     0                      0
# 2  11.356624                     0                      0
# 3  16.594402                     0                      0
# 4  14.250850                     0                      0
#
#    TotalHospitalizedPatients  HomeConfinement  CurrentPositiveCases  \
# 0                          0                0                     0
# 1                          0                0                     0
# 2                          0                0                     0
# 3                          0                0                     0
# 4                          0                0                     0
#
#    NewPositiveCases  Recovered  Deaths  TotalPositiveCases  TestsPerformed
# 0                 0          0       0                   0             NaN
# 1                 0          0       0                   0             NaN
# 2                 0          0       0                   0             NaN
# 3                 0          0       0                   0             NaN
# 4                 0          0       0                   0             NaN

# %%
data.columns
# Out:
# Index(['SNo', 'Date', 'Country', 'RegionCode', 'RegionName', 'Latitude',
#        'Longitude', 'HospitalizedPatients', 'IntensiveCarePatients',
#        'TotalHospitalizedPatients', 'HomeConfinement', 'CurrentPositiveCases',
#        'NewPositiveCases', 'Recovered', 'Deaths', 'TotalPositiveCases',
#        'TestsPerformed'],
#       dtype='object')

# %%
data.tail()
# Out:
#        SNo                 Date Country  RegionCode     RegionName   Latitude  \
# 1444  1444  2020-05-02T17:00:00     ITA           9        Toscana  43.769231
# 1445  1445  2020-05-02T17:00:00     ITA           4    P.A. Trento  46.068935
# 1446  1446  2020-05-02T17:00:00     ITA          10         Umbria  43.106758
# 1447  1447  2020-05-02T17:00:00     ITA           2  Valle d'Aosta  45.737503
# 1448  1448  2020-05-02T17:00:00     ITA           5         Veneto  45.434905
#
#       Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 1444  11.255889                   519                    118
# 1445  11.121231                   138                     19
# 1446  12.388247                    60                     13
# 1447   7.320149                    70                      3
# 1448  12.338452                   970                    108
#
#       TotalHospitalizedPatients  HomeConfinement  CurrentPositiveCases  \
# 1444                        637             4728                  5365
# 1445                        157             1125                  1282
# 1446                         73              123                   196
# 1447                         73               25                    98
# 1448                       1078             6353                  7431
#
#       NewPositiveCases  Recovered  Deaths  TotalPositiveCases  TestsPerformed
# 1444                80       3297     863                9525        112437.0
# 1445                49       2474     425                4181         23380.0
# 1446                 1       1130      68                1394         26463.0
# 1447                 3        901     137                1136          5931.0
# 1448               126       9291    1502               18224        216997.0

# %%
data.describe()
# Out:
#                SNo   RegionCode     Latitude    Longitude  \
# count  1449.000000  1449.000000  1449.000000  1449.000000
# mean    724.000000    10.190476    43.046293    12.225955
# std     418.434583     5.797065     2.489640     2.659866
# min       0.000000     1.000000    38.115697     7.320149
# 25%     362.000000     5.000000    41.125596    11.121231
# 50%     724.000000    10.000000    43.616760    12.388247
# 75%    1086.000000    15.000000    45.434905    13.768136
# max    1448.000000    20.000000    46.499335    16.867367
#
#        HospitalizedPatients  IntensiveCarePatients  TotalHospitalizedPatients  \
# count           1449.000000            1449.000000                 1449.00000
# mean             827.383023             106.458247                  933.84127
# std             1913.290807             207.170799                 2115.43860
# min                0.000000               0.000000                    0.00000
# 25%               30.000000               6.000000                   38.00000
# 50%              163.000000              32.000000                  193.00000
# 75%              671.000000             113.000000                  790.00000
# max            12077.000000            1381.000000                13328.00000
#
#        HomeConfinement  CurrentPositiveCases  NewPositiveCases     Recovered  \
# count      1449.000000           1449.000000       1449.000000   1449.000000
# mean       1943.213251           2877.054520        144.458247   1084.877847
# std        3853.359249           5728.058755        297.175922   3208.327204
# min           0.000000              0.000000        -18.000000      0.000000
# 25%          70.000000            126.000000          7.000000      2.000000
# 50%         570.000000            819.000000         45.000000     76.000000
# 75%        1802.000000           2802.000000        131.000000    655.000000
# max       29593.000000          36667.000000       3251.000000  26146.000000
#
#              Deaths  TotalPositiveCases  TestsPerformed
# count   1449.000000         1449.000000      294.000000
# mean     564.374741         4526.307108    56026.663265
# std     1801.687735        10517.248283    55711.191231
# min        0.000000            0.000000     3482.000000
# 25%        3.000000          141.000000    19474.750000
# 50%       66.000000         1111.000000    32298.000000
# 75%      295.000000         3646.000000    84641.000000
# max    14189.000000        77002.000000   243383.000000

# %%
# to check the null values in the data
data.isnull().sum()
# Out:
# SNo                             0
# Date                            0
# Country                         0
# RegionCode                      0
# RegionName                      0
# Latitude                        0
# Longitude                       0
# HospitalizedPatients            0
# IntensiveCarePatients           0
# TotalHospitalizedPatients       0
# HomeConfinement                 0
# CurrentPositiveCases            0
# NewPositiveCases                0
# Recovered                       0
# Deaths                          0
# TotalPositiveCases              0
# TestsPerformed               1155
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1449 entries, 0 to 1448
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SNo                        1449 non-null   int64
#  1   Date                       1449 non-null   object
#  2   Country                    1449 non-null   object
#  3   RegionCode                 1449 non-null   int64
#  4   RegionName                 1449 non-null   object
#  5   Latitude                   1449 non-null   float64
#  6   Longitude                  1449 non-null   float64
#  7   HospitalizedPatients       1449 non-null   int64
#  8   IntensiveCarePatients      1449 non-null   int64
#  9   TotalHospitalizedPatients  1449 non-null   int64
#  10  HomeConfinement            1449 non-null   int64
#  11  CurrentPositiveCases       1449 non-null   int64
#  12  NewPositiveCases           1449 non-null   int64
#  13  Recovered                  1449 non-null   int64
#  14  Deaths                     1449 non-null   int64
#  15  TotalPositiveCases         1449 non-null   int64
#  16  TestsPerformed             294 non-null    float64
# dtypes: float64(3), int64(11), object(3)
# memory usage: 192.6+ KB

# %%
data.count()
# Out:
# SNo                          1449
# Date                         1449
# Country                      1449
# RegionCode                   1449
# RegionName                   1449
# Latitude                     1449
# Longitude                    1449
# HospitalizedPatients         1449
# IntensiveCarePatients        1449
# TotalHospitalizedPatients    1449
# HomeConfinement              1449
# CurrentPositiveCases         1449
# NewPositiveCases             1449
# Recovered                    1449
# Deaths                       1449
# TotalPositiveCases           1449
# TestsPerformed                294
# dtype: int64

# %%
#relating the variables with scatter plot
sns.relplot(x='TotalPositiveCases',y='Recovered', data=data)

# %%
sns.relplot(x='TotalHospitalizedPatients',y='Recovered', data=data)

# %%
sns.relplot(x='TotalHospitalizedPatients',y='Deaths', data=data)

# %%
sns.relplot(x='TotalHospitalizedPatients',y='Deaths', hue='Recovered', data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x='HomeConfinement',y='TotalPositiveCases',kind='line', data=data)

# %%
sns.relplot(x='HomeConfinement',y='TotalPositiveCases',kind='line',hue='Recovered', data=data)

# %%
sns.catplot(x='Recovered',y='TotalPositiveCases',data=data)

# %%
data.head()
# Out:
#    SNo                 Date Country  RegionCode    RegionName   Latitude  \
# 0    0  2020-02-24T18:00:00     ITA          13       Abruzzo  42.351222
# 1    1  2020-02-24T18:00:00     ITA          17    Basilicata  40.639471
# 2    2  2020-02-24T18:00:00     ITA           4  P.A. Bolzano  46.499335
# 3    3  2020-02-24T18:00:00     ITA          18      Calabria  38.905976
# 4    4  2020-02-24T18:00:00     ITA          15      Campania  40.839566
#
#    Longitude  HospitalizedPatients  IntensiveCarePatients  \
# 0  13.398438                     0                      0
# 1  15.805148                     0                      0
# 2  11.356624                     0                      0
# 3  16.594402                     0                      0
# 4  14.250850                     0                      0
#
#    TotalHospitalizedPatients  HomeConfinement  CurrentPositiveCases  \
# 0                          0                0                     0
# 1                          0                0                     0
# 2                          0                0                     0
# 3                          0                0                     0
# 4                          0                0                     0
#
#    NewPositiveCases  Recovered  Deaths  TotalPositiveCases  TestsPerformed
# 0                 0          0       0                   0             NaN
# 1                 0          0       0                   0             NaN
# 2                 0          0       0                   0             NaN
# 3                 0          0       0                   0             NaN
# 4                 0          0       0                   0             NaN
